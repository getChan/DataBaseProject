# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='ko', tz=360)

# %%
kw_list=["닐로 지나오다"]
pytrends.build_payload(kw_list, cat=0, timeframe='2018-03-24 2018-05-24', geo='KR', gprop='')

# %%
df = pytrends.interest_over_time()
df
# Out:
#             닐로 지나오다  isPartial
# date
# 2018-03-24        0      False
# 2018-03-25       27      False
# 2018-03-26        0      False
# 2018-03-27       24      False
# 2018-03-28        0      False
# 2018-03-29       25      False
# 2018-03-30        0      False
# 2018-03-31       27      False
# 2018-04-01        0      False
# 2018-04-02        0      False
# 2018-04-03        0      False
# 2018-04-04       24      False
# 2018-04-05       36      False
# 2018-04-06       38      False
# 2018-04-07        0      False
# 2018-04-08       39      False
# 2018-04-09       25      False
# 2018-04-10       48      False
# 2018-04-11       49      False
# 2018-04-12       87      False
# 2018-04-13       63      False
# 2018-04-14       91      False
# 2018-04-15       53      False
# 2018-04-16       49      False
# 2018-04-17       61      False
# 2018-04-18       98      False
# 2018-04-19      100      False
# 2018-04-20        0      False
# 2018-04-21       41      False
# ...

# %%
df = pytrends.get_historical_interest(kw_list, year_start=2018, month_start=8, day_start=1, hour_start=0, year_end=2018, month_end=11, day_end=2, hour_end=0, cat=0, geo='KR', gprop='', sleep=60)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-775b09318db5> in <module>()
# ----> 1 df = pytrends.get_historical_interest(kw_list, year_start=2018, month_start=8, day_start=1, hour_start=0, year_end=2018, month_end=11, day_end=2, hour_end=0, cat=0, geo='KR', gprop='', sleep=60)
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytrends\request.py in get_historical_interest(self, keywords, year_start, month_start, day_start, hour_start, year_end, month_end, day_end, hour_end, cat, geo, gprop, sleep)
#     413             # just in case you are rate-limited by Google. Recommended is 60 if you are.
#     414             if sleep > 0:
# --> 415                 time.sleep(sleep)
#     416
#     417         return df
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot as plt

plt.plot(df['닐로 지나오다'])

# %%
plt.plot(df['닐로'], )
