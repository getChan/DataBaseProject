# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='ko', tz=360)

# %%
kw_list=["그날처럼"]
#pytrends.build_payload(kw_list, cat=0, timeframe='2018-01-01 2018-02-08', geo='KR', gprop='')

# %%
#df = pytrends.interest_over_time()
#df

# %%
df = pytrends.get_historical_interest(kw_list, year_start=2018, month_start=1, day_start=1, hour_start=0, year_end=2018, month_end=2, day_end=8, hour_end=0, cat=0, geo='KR', gprop='', sleep=60)
df
# Out:
#                      그날처럼  isPartial
# date
# 2018-01-01 00:00:00    21      False
# 2018-01-01 01:00:00    16      False
# 2018-01-01 02:00:00    32      False
# 2018-01-01 03:00:00    27      False
# 2018-01-01 04:00:00    23      False
# 2018-01-01 05:00:00    19      False
# 2018-01-01 06:00:00    33      False
# 2018-01-01 07:00:00    54      False
# 2018-01-01 08:00:00    30      False
# 2018-01-01 09:00:00    36      False
# 2018-01-01 10:00:00    25      False
# 2018-01-01 11:00:00    27      False
# 2018-01-01 12:00:00    28      False
# 2018-01-01 13:00:00    44      False
# 2018-01-01 14:00:00    52      False
# 2018-01-01 15:00:00    29      False
# 2018-01-01 16:00:00    81      False
# 2018-01-01 17:00:00    50      False
# 2018-01-01 18:00:00    46      False
# 2018-01-01 19:00:00    25      False
# 2018-01-01 20:00:00     0      False
# 2018-01-01 21:00:00     0      False
# 2018-01-01 22:00:00    26      False
# 2018-01-01 23:00:00    11      False
# ...

# %%
from matplotlib import pyplot as plt

# %%
plt.plot(df['그날처럼'])
