# %%
from pytrends.request import TrendReq

pytrends = TrendReq(hl='ko', tz=360)

# %%
kw_list=["좋니"]
pytrends.build_payload(kw_list, cat=0, timeframe='2017-06-22 2018-08-22', geo='KR', gprop='')

# %%
df = pytrends.interest_over_time()
df
# Out:
#              좋니  isPartial
# date
# 2017-06-25    7      False
# 2017-07-02    8      False
# 2017-07-09   11      False
# 2017-07-16   14      False
# 2017-07-23   15      False
# 2017-07-30   15      False
# 2017-08-06   24      False
# 2017-08-13   69      False
# 2017-08-20  100      False
# 2017-08-27   72      False
# 2017-09-03   81      False
# 2017-09-10   86      False
# 2017-09-17   86      False
# 2017-09-24   62      False
# 2017-10-01   70      False
# 2017-10-08   60      False
# 2017-10-15   76      False
# 2017-10-22   51      False
# 2017-10-29   43      False
# 2017-11-05   40      False
# 2017-11-12   43      False
# 2017-11-19   45      False
# 2017-11-26   50      False
# 2017-12-03   42      False
# 2017-12-10   32      False
# 2017-12-17   36      False
# 2017-12-24   33      False
# 2017-12-31   33      False
# 2018-01-07   32      False
# 2018-01-14   29      False
# ...         ...        ...
# 2018-01-28   21      False
# 2018-02-04   25      False
# 2018-02-11   21      False
# 2018-02-18   18      False
# 2018-02-25   18      False
# 2018-03-04   19      False
# 2018-03-11   16      False
# 2018-03-18   17      False
# 2018-03-25   15      False
# 2018-04-01   20      False
# 2018-04-08   15      False
# 2018-04-15   15      False
# 2018-04-22   16      False
# 2018-04-29   10      False
# 2018-05-06    9      False
# 2018-05-13    8      False
# 2018-05-20   10      False
# 2018-05-27   10      False
# 2018-06-03   10      False
# 2018-06-10    9      False
# 2018-06-17    8      False
# 2018-06-24    7      False
# 2018-07-01   10      False
# 2018-07-08    7      False
# 2018-07-15    7      False
# 2018-07-22    9      False
# 2018-07-29    8      False
# 2018-08-05   10      False
# 2018-08-12    5      False
# 2018-08-19    8      False
#
# [61 rows x 2 columns]

# %%
df = pytrends.get_historical_interest(kw_list, year_start=2018, month_start=8, day_start=1, hour_start=0, year_end=2018, month_end=11, day_end=2, hour_end=0, cat=0, geo='KR', gprop='', sleep=60)
df
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-775b09318db5> in <module>()
# ----> 1 df = pytrends.get_historical_interest(kw_list, year_start=2018, month_start=8, day_start=1, hour_start=0, year_end=2018, month_end=11, day_end=2, hour_end=0, cat=0, geo='KR', gprop='', sleep=60)
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pytrends\request.py in get_historical_interest(self, keywords, year_start, month_start, day_start, hour_start, year_end, month_end, day_end, hour_end, cat, geo, gprop, sleep)
#     413             # just in case you are rate-limited by Google. Recommended is 60 if you are.
#     414             if sleep > 0:
# --> 415                 time.sleep(sleep)
#     416
#     417         return df
#
# KeyboardInterrupt:

# %%
from matplotlib import pyplot as plt

plt.plot(df['좋니'])

# %%
plt.plot(df['닐로'], )
